# %%
import numpy as np
import torch
import torch.nn as nn
from copy import deepcopy
import random
import os
import matplotlib.pyplot as plt

# %%
class ReplayBuffer:
    def __init__(self, capacity, device):
        self.capacity = int(capacity) # capacity of the buffer
        self.data = []
        self.index = 0 # index of the next cell to be filled
        self.device = device
    def append(self, s, a, r, s_, d):
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d)
        self.index = (self.index + 1) % self.capacity
    def sample(self, batch_size):
        batch = random.sample(self.data, batch_size)
        return list(map(lambda x:torch.Tensor(np.array(x)).to(self.device), list(zip(*batch))))
    def __len__(self):
        return len(self.data)

# %%
def greedy_action(network, state):
    device = "cuda" if next(network.parameters()).is_cuda else "cpu"
    with torch.no_grad():
        Q = network(torch.Tensor(state).unsqueeze(0).to(device))
        return torch.argmax(Q).item()

# %%
class dqn_agent:
    def __init__(self, config, model):
        device = "cuda" if next(model.parameters()).is_cuda else "cpu"
        self.nb_actions = config['nb_actions']
        self.gamma = config['gamma'] if 'gamma' in config.keys() else 0.95
        self.batch_size = config['batch_size'] if 'batch_size' in config.keys() else 100
        buffer_size = config['buffer_size'] if 'buffer_size' in config.keys() else int(1e5)
        self.memory = ReplayBuffer(buffer_size,device)
        self.epsilon_max = config['epsilon_max'] if 'epsilon_max' in config.keys() else 1.
        self.epsilon_min = config['epsilon_min'] if 'epsilon_min' in config.keys() else 0.01
        self.epsilon_stop = config['epsilon_decay_period'] if 'epsilon_decay_period' in config.keys() else 1000
        self.epsilon_delay = config['epsilon_delay_decay'] if 'epsilon_delay_decay' in config.keys() else 20
        self.epsilon_step = (self.epsilon_max-self.epsilon_min)/self.epsilon_stop
        self.model = model 
        self.target_model = deepcopy(self.model).to(device)
        self.criterion = config['criterion'] if 'criterion' in config.keys() else torch.nn.MSELoss()
        lr = config['learning_rate'] if 'learning_rate' in config.keys() else 0.001
        self.optimizer = config['optimizer'] if 'optimizer' in config.keys() else torch.optim.Adam(self.model.parameters(), lr=lr)
        self.nb_gradient_steps = config['gradient_steps'] if 'gradient_steps' in config.keys() else 1
        self.update_target_strategy = config['update_target_strategy'] if 'update_target_strategy' in config.keys() else 'replace'
        self.update_target_freq = config['update_target_freq'] if 'update_target_freq' in config.keys() else 20
        self.update_target_tau = config['update_target_tau'] if 'update_target_tau' in config.keys() else 0.005
    
    def gradient_step(self):
        if len(self.memory) > self.batch_size:
            X, A, R, Y, D = self.memory.sample(self.batch_size)
            QYmax = self.target_model(Y).max(1)[0].detach()
            update = torch.addcmul(R, 1-D, QYmax, value=self.gamma)
            QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
            loss = self.criterion(QXA, update.unsqueeze(1))
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step() 
    
    def train(self, env, max_episode):
        episode_return = []
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0
        while episode < max_episode:
            # update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon-self.epsilon_step)
            # select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                action = greedy_action(self.model, state)
            # step
            next_state, reward, done, trunc, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward
            # train
            for _ in range(self.nb_gradient_steps): 
                self.gradient_step()
            # update target network if needed
            if self.update_target_strategy == 'replace':
                if step % self.update_target_freq == 0: 
                    self.target_model.load_state_dict(self.model.state_dict())
            if self.update_target_strategy == 'ema':
                target_state_dict = self.target_model.state_dict()
                model_state_dict = self.model.state_dict()
                tau = self.update_target_tau
                for key in model_state_dict:
                    target_state_dict[key] = tau*model_state_dict[key] + (1-tau)*target_state_dict[key]
                self.target_model.load_state_dict(target_state_dict)
            # next transition
            step += 1
            if done or trunc:
                if episode > 0:
                    if episode_cum_reward > best_reward:
                        best_reward = episode_cum_reward
                        torch.save(self.model, os.path.join(os.getcwd(), "models/DQN5.pt"))
                else:
                    best_reward = episode_cum_reward
                    torch.save(self.model, os.path.join(os.getcwd(), "models/DQN5.pt"))

                episode += 1
                print("Episode ", '{:3d}'.format(episode), 
                      ", epsilon ", '{:6.2f}'.format(epsilon), 
                      ", batch size ", '{:5d}'.format(len(self.memory)), 
                      ", episode return ", "{:.2e}".format(episode_cum_reward),
                      sep='')
                state, _ = env.reset()
                episode_return.append(episode_cum_reward)
                episode_cum_reward = 0

            else:
                state = next_state
        return episode_return

# %%
from gymnasium.wrappers import TimeLimit
from env_hiv import HIVPatient

env = TimeLimit(
    env=HIVPatient(domain_randomization=False), max_episode_steps=200
)  # The time wrapper limits the number of steps in an episode at 200.
# Now is the floor is yours to implement the agent and train it.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# Declare network
state_dim = env.observation_space.shape[0]
n_action = env.action_space.n 
nb_neurons=128
DQN = torch.nn.Sequential(nn.Linear(state_dim, nb_neurons),
                          nn.ReLU(),
                          nn.Linear(nb_neurons, nb_neurons),
                          nn.ReLU(),
                          nn.Linear(nb_neurons, n_action)).to(device)

# DQN config
config = {'nb_actions': n_action,
        'learning_rate': 5e-4,
        'gamma': 0.95,
        'buffer_size': 2048*5,
        'epsilon_min': 0.05,
        'epsilon_max': 1,
        'epsilon_decay_period': 200*50,
        'epsilon_delay_decay': 200*10,
        'batch_size': 2048,
        'gradient_steps': 20,
        'update_target_strategy': 'ema', # or 'ema'
        'update_target_freq': 20,
        'update_target_tau': 0.005,
        'criterion': torch.nn.SmoothL1Loss()}

# Train agent
agent = dqn_agent(config, DQN)
scores = agent.train(env, 200)
plt.plot(scores)
# Out:
# cuda
# Episode   1, epsilon   1.00, batch size   200, episode return 8.07e+06
# Episode   2, epsilon   1.00, batch size   400, episode return 9.88e+06
# Episode   3, epsilon   1.00, batch size   600, episode return 9.58e+06
# Episode   4, epsilon   1.00, batch size   800, episode return 1.10e+07
# Episode   5, epsilon   1.00, batch size  1000, episode return 1.08e+07
# Episode   6, epsilon   1.00, batch size  1200, episode return 1.12e+07
# Episode   7, epsilon   1.00, batch size  1400, episode return 1.01e+07
# Episode   8, epsilon   1.00, batch size  1600, episode return 6.17e+06
# Episode   9, epsilon   1.00, batch size  1800, episode return 1.74e+07
# Episode  10, epsilon   1.00, batch size  2000, episode return 8.37e+06
# Episode  11, epsilon   0.98, batch size  2200, episode return 1.07e+07
# Episode  12, epsilon   0.96, batch size  2400, episode return 9.77e+06
# Episode  13, epsilon   0.94, batch size  2600, episode return 1.20e+07
# Episode  14, epsilon   0.92, batch size  2800, episode return 1.05e+07
# Episode  15, epsilon   0.91, batch size  3000, episode return 1.27e+07
# Episode  16, epsilon   0.89, batch size  3200, episode return 1.24e+07
# Episode  17, epsilon   0.87, batch size  3400, episode return 1.38e+07
# Episode  18, epsilon   0.85, batch size  3600, episode return 1.11e+07
# Episode  19, epsilon   0.83, batch size  3800, episode return 2.22e+07
# Episode  20, epsilon   0.81, batch size  4000, episode return 1.82e+07
# Episode  21, epsilon   0.79, batch size  4200, episode return 1.34e+07
# Episode  22, epsilon   0.77, batch size  4400, episode return 1.20e+07
# Episode  23, epsilon   0.75, batch size  4600, episode return 1.37e+07
# Episode  24, epsilon   0.73, batch size  4800, episode return 1.08e+07
# Episode  25, epsilon   0.72, batch size  5000, episode return 1.61e+07
# Episode  26, epsilon   0.70, batch size  5200, episode return 1.39e+07
# Episode  27, epsilon   0.68, batch size  5400, episode return 1.69e+07
# Episode  28, epsilon   0.66, batch size  5600, episode return 1.04e+07
# Episode  29, epsilon   0.64, batch size  5800, episode return 1.46e+07
# Episode  30, epsilon   0.62, batch size  6000, episode return 2.36e+07
# Episode  31, epsilon   0.60, batch size  6200, episode return 1.43e+07
# Episode  32, epsilon   0.58, batch size  6400, episode return 2.76e+07
# Episode  33, epsilon   0.56, batch size  6600, episode return 1.79e+07
# Episode  34, epsilon   0.54, batch size  6800, episode return 2.04e+07
# Episode  35, epsilon   0.53, batch size  7000, episode return 2.00e+07
# Episode  36, epsilon   0.51, batch size  7200, episode return 2.02e+07
# Episode  37, epsilon   0.49, batch size  7400, episode return 2.44e+07
# Episode  38, epsilon   0.47, batch size  7600, episode return 2.03e+07
# Episode  39, epsilon   0.45, batch size  7800, episode return 3.90e+07
# Episode  40, epsilon   0.43, batch size  8000, episode return 3.56e+07
# Episode  41, epsilon   0.41, batch size  8200, episode return 3.08e+07
# Episode  42, epsilon   0.39, batch size  8400, episode return 4.96e+07
# Episode  43, epsilon   0.37, batch size  8600, episode return 2.56e+07
# Episode  44, epsilon   0.35, batch size  8800, episode return 4.02e+07
# Episode  45, epsilon   0.34, batch size  9000, episode return 2.78e+07
# Episode  46, epsilon   0.32, batch size  9200, episode return 4.86e+07
# Episode  47, epsilon   0.30, batch size  9400, episode return 7.03e+07
# Episode  48, epsilon   0.28, batch size  9600, episode return 4.61e+07
# Episode  49, epsilon   0.26, batch size  9800, episode return 7.19e+07
# Episode  50, epsilon   0.24, batch size 10000, episode return 8.94e+07
# Episode  51, epsilon   0.22, batch size 10200, episode return 1.25e+08
# Episode  52, epsilon   0.20, batch size 10240, episode return 9.87e+07
# Episode  53, epsilon   0.18, batch size 10240, episode return 8.97e+07
# Episode  54, epsilon   0.16, batch size 10240, episode return 8.76e+07
# Episode  55, epsilon   0.15, batch size 10240, episode return 1.11e+08
# Episode  56, epsilon   0.13, batch size 10240, episode return 1.54e+08
# Episode  57, epsilon   0.11, batch size 10240, episode return 1.33e+08
# Episode  58, epsilon   0.09, batch size 10240, episode return 1.06e+08
# Episode  59, epsilon   0.07, batch size 10240, episode return 1.02e+08
# Episode  60, epsilon   0.05, batch size 10240, episode return 1.11e+08
# Episode  61, epsilon   0.05, batch size 10240, episode return 1.14e+08
# Episode  62, epsilon   0.05, batch size 10240, episode return 1.23e+08
# Episode  63, epsilon   0.05, batch size 10240, episode return 3.62e+07
# Episode  64, epsilon   0.05, batch size 10240, episode return 8.92e+07
# Episode  65, epsilon   0.05, batch size 10240, episode return 1.50e+08
# Episode  66, epsilon   0.05, batch size 10240, episode return 1.99e+08
# Episode  67, epsilon   0.05, batch size 10240, episode return 2.47e+08
# Episode  68, epsilon   0.05, batch size 10240, episode return 1.91e+08
# Episode  69, epsilon   0.05, batch size 10240, episode return 2.24e+08
# Episode  70, epsilon   0.05, batch size 10240, episode return 9.44e+08
# Episode  71, epsilon   0.05, batch size 10240, episode return 2.10e+08
# Episode  72, epsilon   0.05, batch size 10240, episode return 1.46e+08
# Episode  73, epsilon   0.05, batch size 10240, episode return 1.58e+09
# Episode  74, epsilon   0.05, batch size 10240, episode return 1.01e+08
# Episode  75, epsilon   0.05, batch size 10240, episode return 5.21e+08
# Episode  76, epsilon   0.05, batch size 10240, episode return 1.53e+08
# Episode  77, epsilon   0.05, batch size 10240, episode return 9.07e+07
# Episode  78, epsilon   0.05, batch size 10240, episode return 1.02e+08
# Episode  79, epsilon   0.05, batch size 10240, episode return 1.51e+08
# Episode  80, epsilon   0.05, batch size 10240, episode return 2.15e+08
# Episode  81, epsilon   0.05, batch size 10240, episode return 8.33e+07
# Episode  82, epsilon   0.05, batch size 10240, episode return 3.60e+07
# Episode  83, epsilon   0.05, batch size 10240, episode return 5.18e+07
# Episode  84, epsilon   0.05, batch size 10240, episode return 2.15e+07
# Episode  85, epsilon   0.05, batch size 10240, episode return 3.13e+07
# Episode  86, epsilon   0.05, batch size 10240, episode return 4.93e+07
# Episode  87, epsilon   0.05, batch size 10240, episode return 2.94e+07
# Episode  88, epsilon   0.05, batch size 10240, episode return 2.98e+07
# Episode  89, epsilon   0.05, batch size 10240, episode return 3.07e+07
# Episode  90, epsilon   0.05, batch size 10240, episode return 6.48e+07
# Episode  91, epsilon   0.05, batch size 10240, episode return 4.00e+07
# Episode  92, epsilon   0.05, batch size 10240, episode return 4.74e+07
# Episode  93, epsilon   0.05, batch size 10240, episode return 3.35e+07
# Episode  94, epsilon   0.05, batch size 10240, episode return 4.05e+07
# Episode  95, epsilon   0.05, batch size 10240, episode return 4.11e+07
# Episode  96, epsilon   0.05, batch size 10240, episode return 2.36e+07
# Episode  97, epsilon   0.05, batch size 10240, episode return 1.42e+07
# Episode  98, epsilon   0.05, batch size 10240, episode return 1.06e+07
# Episode  99, epsilon   0.05, batch size 10240, episode return 1.50e+07
# Episode 100, epsilon   0.05, batch size 10240, episode return 1.63e+07
# Episode 101, epsilon   0.05, batch size 10240, episode return 1.19e+07
# Episode 102, epsilon   0.05, batch size 10240, episode return 2.32e+07
# Episode 103, epsilon   0.05, batch size 10240, episode return 1.24e+07
# Episode 104, epsilon   0.05, batch size 10240, episode return 1.48e+07
# Episode 105, epsilon   0.05, batch size 10240, episode return 3.29e+07
# Episode 106, epsilon   0.05, batch size 10240, episode return 2.33e+07
# Episode 107, epsilon   0.05, batch size 10240, episode return 8.48e+06
# Episode 108, epsilon   0.05, batch size 10240, episode return 1.69e+07
# Episode 109, epsilon   0.05, batch size 10240, episode return 1.11e+07
# Episode 110, epsilon   0.05, batch size 10240, episode return 3.50e+07
# Episode 111, epsilon   0.05, batch size 10240, episode return 1.65e+07
# Episode 112, epsilon   0.05, batch size 10240, episode return 1.83e+07
# Episode 113, epsilon   0.05, batch size 10240, episode return 1.88e+07
# Episode 114, epsilon   0.05, batch size 10240, episode return 2.27e+07
# Episode 115, epsilon   0.05, batch size 10240, episode return 1.80e+07
# Episode 116, epsilon   0.05, batch size 10240, episode return 1.78e+07
# Episode 117, epsilon   0.05, batch size 10240, episode return 2.68e+07
# Episode 118, epsilon   0.05, batch size 10240, episode return 1.78e+07
# Episode 119, epsilon   0.05, batch size 10240, episode return 1.59e+07
# Episode 120, epsilon   0.05, batch size 10240, episode return 1.86e+07
# Episode 121, epsilon   0.05, batch size 10240, episode return 2.09e+07
# Episode 122, epsilon   0.05, batch size 10240, episode return 1.85e+07
# Episode 123, epsilon   0.05, batch size 10240, episode return 1.46e+07
# Episode 124, epsilon   0.05, batch size 10240, episode return 1.74e+07
# Episode 125, epsilon   0.05, batch size 10240, episode return 1.39e+07
# Episode 126, epsilon   0.05, batch size 10240, episode return 1.11e+07
# Episode 127, epsilon   0.05, batch size 10240, episode return 1.27e+07
# Episode 128, epsilon   0.05, batch size 10240, episode return 2.06e+07
# Episode 129, epsilon   0.05, batch size 10240, episode return 3.07e+07
# Episode 130, epsilon   0.05, batch size 10240, episode return 2.17e+07
# Episode 131, epsilon   0.05, batch size 10240, episode return 2.24e+07
# Episode 132, epsilon   0.05, batch size 10240, episode return 2.38e+07
# Episode 133, epsilon   0.05, batch size 10240, episode return 2.04e+07
# Episode 134, epsilon   0.05, batch size 10240, episode return 1.87e+07
# Episode 135, epsilon   0.05, batch size 10240, episode return 4.08e+07
# Episode 136, epsilon   0.05, batch size 10240, episode return 3.49e+07
# Episode 137, epsilon   0.05, batch size 10240, episode return 3.88e+07
# Episode 138, epsilon   0.05, batch size 10240, episode return 8.34e+07
# Episode 139, epsilon   0.05, batch size 10240, episode return 4.44e+07
# Episode 140, epsilon   0.05, batch size 10240, episode return 9.27e+07
# Episode 141, epsilon   0.05, batch size 10240, episode return 7.78e+07
# Episode 142, epsilon   0.05, batch size 10240, episode return 8.63e+07
# Episode 143, epsilon   0.05, batch size 10240, episode return 7.82e+07
# Episode 144, epsilon   0.05, batch size 10240, episode return 6.98e+07
# Episode 145, epsilon   0.05, batch size 10240, episode return 1.23e+07
# Episode 146, epsilon   0.05, batch size 10240, episode return 1.41e+07
# Episode 147, epsilon   0.05, batch size 10240, episode return 1.20e+07
# Episode 148, epsilon   0.05, batch size 10240, episode return 2.07e+07
# Episode 149, epsilon   0.05, batch size 10240, episode return 1.41e+07
# Episode 150, epsilon   0.05, batch size 10240, episode return 9.80e+06
# Episode 151, epsilon   0.05, batch size 10240, episode return 7.78e+06
# Episode 152, epsilon   0.05, batch size 10240, episode return 2.64e+07
# Episode 153, epsilon   0.05, batch size 10240, episode return 6.65e+07
# Episode 154, epsilon   0.05, batch size 10240, episode return 1.32e+07
# Episode 155, epsilon   0.05, batch size 10240, episode return 7.23e+07
# Episode 156, epsilon   0.05, batch size 10240, episode return 1.02e+07
# Episode 157, epsilon   0.05, batch size 10240, episode return 1.04e+08
# Episode 158, epsilon   0.05, batch size 10240, episode return 5.58e+06
# Episode 159, epsilon   0.05, batch size 10240, episode return 1.51e+07
# Episode 160, epsilon   0.05, batch size 10240, episode return 1.12e+07
# Episode 161, epsilon   0.05, batch size 10240, episode return 7.07e+07
# Episode 162, epsilon   0.05, batch size 10240, episode return 6.84e+07
# Episode 163, epsilon   0.05, batch size 10240, episode return 1.07e+08
# Episode 164, epsilon   0.05, batch size 10240, episode return 7.88e+07
# Episode 165, epsilon   0.05, batch size 10240, episode return 2.93e+07
# Episode 166, epsilon   0.05, batch size 10240, episode return 6.30e+07
# Episode 167, epsilon   0.05, batch size 10240, episode return 1.12e+08
# Episode 168, epsilon   0.05, batch size 10240, episode return 9.77e+07
# Episode 169, epsilon   0.05, batch size 10240, episode return 1.53e+08
# Episode 170, epsilon   0.05, batch size 10240, episode return 4.44e+07
# Episode 171, epsilon   0.05, batch size 10240, episode return 1.04e+08
# Episode 172, epsilon   0.05, batch size 10240, episode return 1.99e+08
# Episode 173, epsilon   0.05, batch size 10240, episode return 1.92e+08
# Episode 174, epsilon   0.05, batch size 10240, episode return 2.46e+08
# Episode 175, epsilon   0.05, batch size 10240, episode return 1.26e+08
# Episode 176, epsilon   0.05, batch size 10240, episode return 3.04e+08
# Episode 177, epsilon   0.05, batch size 10240, episode return 9.75e+07
# Episode 178, epsilon   0.05, batch size 10240, episode return 9.36e+07
# Episode 179, epsilon   0.05, batch size 10240, episode return 5.93e+08
# Episode 180, epsilon   0.05, batch size 10240, episode return 7.02e+07
# Episode 181, epsilon   0.05, batch size 10240, episode return 4.90e+08
# Episode 182, epsilon   0.05, batch size 10240, episode return 5.31e+08
# Episode 183, epsilon   0.05, batch size 10240, episode return 4.45e+08
# Episode 184, epsilon   0.05, batch size 10240, episode return 1.91e+08
# Episode 185, epsilon   0.05, batch size 10240, episode return 3.23e+08
# Episode 186, epsilon   0.05, batch size 10240, episode return 5.51e+08
# Episode 187, epsilon   0.05, batch size 10240, episode return 5.41e+08
# Episode 188, epsilon   0.05, batch size 10240, episode return 1.59e+09
# Episode 189, epsilon   0.05, batch size 10240, episode return 9.34e+08
# Episode 190, epsilon   0.05, batch size 10240, episode return 1.21e+09
# Episode 191, epsilon   0.05, batch size 10240, episode return 2.84e+08
# Episode 192, epsilon   0.05, batch size 10240, episode return 1.42e+09
# Episode 193, epsilon   0.05, batch size 10240, episode return 3.40e+08
# Episode 194, epsilon   0.05, batch size 10240, episode return 2.18e+08
# Episode 195, epsilon   0.05, batch size 10240, episode return 1.63e+09
# Episode 196, epsilon   0.05, batch size 10240, episode return 2.13e+09
# Episode 197, epsilon   0.05, batch size 10240, episode return 7.67e+08
# Episode 198, epsilon   0.05, batch size 10240, episode return 1.43e+08
# Episode 199, epsilon   0.05, batch size 10240, episode return 1.66e+09
# Episode 200, epsilon   0.05, batch size 10240, episode return 1.70e+08
