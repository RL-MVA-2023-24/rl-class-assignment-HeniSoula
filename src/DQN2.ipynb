# %%
import random
import torch
import numpy as np

class ReplayBuffer:
    def __init__(self, capacity, device):
        self.capacity = int(capacity) # capacity of the buffer
        self.data = []
        self.index = 0 # index of the next cell to be filled
        self.device = device
    def append(self, s, a, r, s_, d):
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d)
        self.index = (self.index + 1) % self.capacity
    def sample(self, batch_size):
        batch = random.sample(self.data, batch_size)
        return list(map(lambda x:torch.Tensor(np.array(x)).to(self.device), list(zip(*batch))))
    def __len__(self):
        return len(self.data)

# %%
import torch

def greedy_action(network, state):
    device = "cuda" if next(network.parameters()).is_cuda else "cpu"
    with torch.no_grad():
        Q = network(torch.Tensor(state).unsqueeze(0).to(device))
        return torch.argmax(Q).item()

# %%
import numpy as np
import torch
import torch.nn as nn

class dqn_agent:
    def __init__(self, config, model):
        device = "cuda" if next(model.parameters()).is_cuda else "cpu"
        self.gamma = config['gamma']
        self.batch_size = config['batch_size']
        self.nb_actions = config['nb_actions']
        self.memory = ReplayBuffer(config['buffer_size'], device)
        self.epsilon_max = config['epsilon_max']
        self.epsilon_min = config['epsilon_min']
        self.epsilon_stop = config['epsilon_decay_period']
        self.epsilon_delay = config['epsilon_delay_decay']
        self.epsilon_step = (self.epsilon_max-self.epsilon_min)/self.epsilon_stop
        self.model = model 
        self.criterion = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=config['learning_rate'])
    
    def gradient_step(self):
        if len(self.memory) > self.batch_size:
            X, A, R, Y, D = self.memory.sample(self.batch_size)
            QYmax = self.model(Y).max(1)[0].detach()
            #update = torch.addcmul(R, self.gamma, 1-D, QYmax)
            update = torch.addcmul(R, 1-D, QYmax, value=self.gamma)
            QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
            loss = self.criterion(QXA, update.unsqueeze(1))
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step() 
    
    def train(self, env, max_episode):
        episode_return = []
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0

        while episode < max_episode:
            # update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon-self.epsilon_step)

            # select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                action = greedy_action(self.model, state)

            # step
            next_state, reward, done, trunc, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward

            # train
            self.gradient_step()

            # next transition
            step += 1
            if done or trunc:
                episode += 1
                print("Episode ", '{:3d}'.format(episode), 
                      ", epsilon ", '{:6.2f}'.format(epsilon), 
                      ", batch size ", '{:5d}'.format(len(self.memory)), 
                      ", episode return ", '{:4.1f}'.format(episode_cum_reward),
                      sep='')
                state, _ = env.reset()
                episode_return.append(episode_cum_reward)
                episode_cum_reward = 0
            else:
                state = next_state

        return episode_return

# %%
from gymnasium.wrappers import TimeLimit
from env_hiv import HIVPatient

env = TimeLimit(
    env=HIVPatient(domain_randomization=False), max_episode_steps=200
)  # The time wrapper limits the number of steps in an episode at 200.
# Now is the floor is yours to implement the agent and train it.

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# Declare network
state_dim = env.observation_space.shape[0]
n_action = env.action_space.n 
nb_neurons=24
DQN = torch.nn.Sequential(nn.Linear(state_dim, nb_neurons),
                          nn.ReLU(),
                          nn.Linear(nb_neurons, nb_neurons),
                          nn.ReLU(), 
                          nn.Linear(nb_neurons, n_action)).to(device)

# DQN config
config = {'nb_actions': env.action_space.n,
          'learning_rate': 0.001,
          'gamma': 0.9,
          'buffer_size': 1000,
          'epsilon_min': 0.01,
          'epsilon_max': 1.,
          'epsilon_decay_period': 1000,
          'epsilon_delay_decay': 20,
          'batch_size': 20}

# Train agent
agent = dqn_agent(config, DQN)
scores = agent.train(env, 200)
plt.plot(scores)
# Out:
# cuda
# Episode   1, epsilon   0.82, batch size   200, episode return 10019009.2
# Episode   2, epsilon   0.62, batch size   400, episode return 7172760.5
# Episode   3, epsilon   0.43, batch size   600, episode return 10684582.2
# Episode   4, epsilon   0.23, batch size   800, episode return 13614077.1
# Episode   5, epsilon   0.03, batch size  1000, episode return 18860766.1
# Episode   6, epsilon   0.01, batch size  1000, episode return 14574115.3
# Episode   7, epsilon   0.01, batch size  1000, episode return 12426726.9
# Episode   8, epsilon   0.01, batch size  1000, episode return 9170531.8
# Episode   9, epsilon   0.01, batch size  1000, episode return 7198001.7
# Episode  10, epsilon   0.01, batch size  1000, episode return 8727062.4
# Episode  11, epsilon   0.01, batch size  1000, episode return 8689166.1
# Episode  12, epsilon   0.01, batch size  1000, episode return 6351415.2
# Episode  13, epsilon   0.01, batch size  1000, episode return 7187617.4
# Episode  14, epsilon   0.01, batch size  1000, episode return 7181779.1
# Episode  15, epsilon   0.01, batch size  1000, episode return 6733011.9
# Episode  16, epsilon   0.01, batch size  1000, episode return 7389099.4
# Episode  17, epsilon   0.01, batch size  1000, episode return 6729484.0
# Episode  18, epsilon   0.01, batch size  1000, episode return 8332196.1
# Episode  19, epsilon   0.01, batch size  1000, episode return 8224319.7
# Episode  20, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  21, epsilon   0.01, batch size  1000, episode return 8236260.3
# Episode  22, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  23, epsilon   0.01, batch size  1000, episode return 7210892.6
# Episode  24, epsilon   0.01, batch size  1000, episode return 11063578.0
# Episode  25, epsilon   0.01, batch size  1000, episode return 8332196.1
# Episode  26, epsilon   0.01, batch size  1000, episode return 7423804.0
# Episode  27, epsilon   0.01, batch size  1000, episode return 7978476.5
# Episode  28, epsilon   0.01, batch size  1000, episode return 8518882.5
# Episode  29, epsilon   0.01, batch size  1000, episode return 8293099.1
# Episode  30, epsilon   0.01, batch size  1000, episode return 10512724.9
# Episode  31, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  32, epsilon   0.01, batch size  1000, episode return 14171272.4
# Episode  33, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  34, epsilon   0.01, batch size  1000, episode return 8023445.7
# Episode  35, epsilon   0.01, batch size  1000, episode return 8389043.5
# Episode  36, epsilon   0.01, batch size  1000, episode return 8629871.3
# Episode  37, epsilon   0.01, batch size  1000, episode return 7936029.3
# Episode  38, epsilon   0.01, batch size  1000, episode return 8458566.3
# Episode  39, epsilon   0.01, batch size  1000, episode return 7992817.6
# Episode  40, epsilon   0.01, batch size  1000, episode return 6971755.5
# Episode  41, epsilon   0.01, batch size  1000, episode return 7365790.4
# Episode  42, epsilon   0.01, batch size  1000, episode return 10420791.3
# Episode  43, epsilon   0.01, batch size  1000, episode return 11219040.1
# Episode  44, epsilon   0.01, batch size  1000, episode return 7970246.3
# Episode  45, epsilon   0.01, batch size  1000, episode return 7724227.0
# Episode  46, epsilon   0.01, batch size  1000, episode return 7916294.1
# Episode  47, epsilon   0.01, batch size  1000, episode return 8118930.0
# Episode  48, epsilon   0.01, batch size  1000, episode return 10317701.3
# Episode  49, epsilon   0.01, batch size  1000, episode return 9140869.7
# Episode  50, epsilon   0.01, batch size  1000, episode return 10079847.5
# Episode  51, epsilon   0.01, batch size  1000, episode return 8839050.8
# Episode  52, epsilon   0.01, batch size  1000, episode return 9436367.6
# Episode  53, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  54, epsilon   0.01, batch size  1000, episode return 7199076.1
# Episode  55, epsilon   0.01, batch size  1000, episode return 7321031.9
# Episode  56, epsilon   0.01, batch size  1000, episode return 8621492.4
# Episode  57, epsilon   0.01, batch size  1000, episode return 7163661.0
# Episode  58, epsilon   0.01, batch size  1000, episode return 8818510.4
# Episode  59, epsilon   0.01, batch size  1000, episode return 9103550.9
# Episode  60, epsilon   0.01, batch size  1000, episode return 8322156.2
# Episode  61, epsilon   0.01, batch size  1000, episode return 7118133.9
# Episode  62, epsilon   0.01, batch size  1000, episode return 11550854.0
# Episode  63, epsilon   0.01, batch size  1000, episode return 10811427.2
# Episode  64, epsilon   0.01, batch size  1000, episode return 7798397.0
# Episode  65, epsilon   0.01, batch size  1000, episode return 14086862.2
# Episode  66, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  67, epsilon   0.01, batch size  1000, episode return 7319774.7
# Episode  68, epsilon   0.01, batch size  1000, episode return 6777395.6
# Episode  69, epsilon   0.01, batch size  1000, episode return 7797416.3
# Episode  70, epsilon   0.01, batch size  1000, episode return 9483804.7
# Episode  71, epsilon   0.01, batch size  1000, episode return 9738564.8
# Episode  72, epsilon   0.01, batch size  1000, episode return 10900167.2
# Episode  73, epsilon   0.01, batch size  1000, episode return 9698515.3
# Episode  74, epsilon   0.01, batch size  1000, episode return 6908248.6
# Episode  75, epsilon   0.01, batch size  1000, episode return 7282893.3
# Episode  76, epsilon   0.01, batch size  1000, episode return 8638468.9
# Episode  77, epsilon   0.01, batch size  1000, episode return 7670389.1
# Episode  78, epsilon   0.01, batch size  1000, episode return 8203570.9
# Episode  79, epsilon   0.01, batch size  1000, episode return 9487849.5
# Episode  80, epsilon   0.01, batch size  1000, episode return 7205865.8
# Episode  81, epsilon   0.01, batch size  1000, episode return 8725153.1
# Episode  82, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  83, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  84, epsilon   0.01, batch size  1000, episode return 7980172.9
# Episode  85, epsilon   0.01, batch size  1000, episode return 7497648.8
# Episode  86, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  87, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  88, epsilon   0.01, batch size  1000, episode return 6752260.2
# Episode  89, epsilon   0.01, batch size  1000, episode return 7543053.4
# Episode  90, epsilon   0.01, batch size  1000, episode return 8962867.5
# Episode  91, epsilon   0.01, batch size  1000, episode return 8328130.4
# Episode  92, epsilon   0.01, batch size  1000, episode return 9289289.5
# Episode  93, epsilon   0.01, batch size  1000, episode return 7088264.4
# Episode  94, epsilon   0.01, batch size  1000, episode return 8690683.7
# Episode  95, epsilon   0.01, batch size  1000, episode return 8110172.3
# Episode  96, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode  97, epsilon   0.01, batch size  1000, episode return 7914225.1
# Episode  98, epsilon   0.01, batch size  1000, episode return 9027060.8
# Episode  99, epsilon   0.01, batch size  1000, episode return 8368903.1
# Episode 100, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode 101, epsilon   0.01, batch size  1000, episode return 6467437.0
# Episode 102, epsilon   0.01, batch size  1000, episode return 6640914.7
# Episode 103, epsilon   0.01, batch size  1000, episode return 7986875.2
# Episode 104, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode 105, epsilon   0.01, batch size  1000, episode return 7902650.4
# Episode 106, epsilon   0.01, batch size  1000, episode return 7347980.1
# Episode 107, epsilon   0.01, batch size  1000, episode return 6995303.0
# Episode 108, epsilon   0.01, batch size  1000, episode return 8103721.1
# Episode 109, epsilon   0.01, batch size  1000, episode return 8870179.6
# Episode 110, epsilon   0.01, batch size  1000, episode return 7898146.6
# Episode 111, epsilon   0.01, batch size  1000, episode return 8639872.7
# Episode 112, epsilon   0.01, batch size  1000, episode return 10623559.1
# Episode 113, epsilon   0.01, batch size  1000, episode return 9037433.8
# Episode 114, epsilon   0.01, batch size  1000, episode return 8989795.2
# Episode 115, epsilon   0.01, batch size  1000, episode return 7358496.5
# Episode 116, epsilon   0.01, batch size  1000, episode return 9983220.0
# Episode 117, epsilon   0.01, batch size  1000, episode return 7069142.1
# Episode 118, epsilon   0.01, batch size  1000, episode return 9241484.4
# Episode 119, epsilon   0.01, batch size  1000, episode return 9392794.4
# Episode 120, epsilon   0.01, batch size  1000, episode return 9615349.7
# Episode 121, epsilon   0.01, batch size  1000, episode return 7464557.8
# Episode 122, epsilon   0.01, batch size  1000, episode return 7194549.9
# Episode 123, epsilon   0.01, batch size  1000, episode return 8208169.4
# Episode 124, epsilon   0.01, batch size  1000, episode return 7180683.7
# Episode 125, epsilon   0.01, batch size  1000, episode return 8917428.7
# Episode 126, epsilon   0.01, batch size  1000, episode return 8339102.9
# Episode 127, epsilon   0.01, batch size  1000, episode return 8179425.9
# Episode 128, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode 129, epsilon   0.01, batch size  1000, episode return 6850583.9
# Episode 130, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode 131, epsilon   0.01, batch size  1000, episode return 8952079.9
# Episode 132, epsilon   0.01, batch size  1000, episode return 10557736.9
# Episode 133, epsilon   0.01, batch size  1000, episode return 9295977.3
# Episode 134, epsilon   0.01, batch size  1000, episode return 8851536.2
# Episode 135, epsilon   0.01, batch size  1000, episode return 8193783.4
# Episode 136, epsilon   0.01, batch size  1000, episode return 7969143.5
# Episode 137, epsilon   0.01, batch size  1000, episode return 12118991.8
# Episode 138, epsilon   0.01, batch size  1000, episode return 13162780.0
# Episode 139, epsilon   0.01, batch size  1000, episode return 8869495.5
# Episode 140, epsilon   0.01, batch size  1000, episode return 6857657.9
# Episode 141, epsilon   0.01, batch size  1000, episode return 8190910.3
# Episode 142, epsilon   0.01, batch size  1000, episode return 6787976.8
# Episode 143, epsilon   0.01, batch size  1000, episode return 8945189.3
# Episode 144, epsilon   0.01, batch size  1000, episode return 7004890.0
# Episode 145, epsilon   0.01, batch size  1000, episode return 6737312.5
# Episode 146, epsilon   0.01, batch size  1000, episode return 6921647.5
# Episode 147, epsilon   0.01, batch size  1000, episode return 8414328.5
# Episode 148, epsilon   0.01, batch size  1000, episode return 8386291.1
# Episode 149, epsilon   0.01, batch size  1000, episode return 9287658.8
# Episode 150, epsilon   0.01, batch size  1000, episode return 12202914.4
# Episode 151, epsilon   0.01, batch size  1000, episode return 6777395.6
# Episode 152, epsilon   0.01, batch size  1000, episode return 8964574.2
# Episode 153, epsilon   0.01, batch size  1000, episode return 12230290.8
# Episode 154, epsilon   0.01, batch size  1000, episode return 6777395.6
# Episode 155, epsilon   0.01, batch size  1000, episode return 10321844.2
# Episode 156, epsilon   0.01, batch size  1000, episode return 6777395.6
# Episode 157, epsilon   0.01, batch size  1000, episode return 8181316.9
# Episode 158, epsilon   0.01, batch size  1000, episode return 6409049.8
# Episode 159, epsilon   0.01, batch size  1000, episode return 6777395.6
# Episode 160, epsilon   0.01, batch size  1000, episode return 13431937.2
# Episode 161, epsilon   0.01, batch size  1000, episode return 9739018.7
# Episode 162, epsilon   0.01, batch size  1000, episode return 8846308.9
# Episode 163, epsilon   0.01, batch size  1000, episode return 8883747.9
# Episode 164, epsilon   0.01, batch size  1000, episode return 8149911.8
# Episode 165, epsilon   0.01, batch size  1000, episode return 6932183.8
# Episode 166, epsilon   0.01, batch size  1000, episode return 7881715.6
# Episode 167, epsilon   0.01, batch size  1000, episode return 8609450.0
# Episode 168, epsilon   0.01, batch size  1000, episode return 9064434.4
# Episode 169, epsilon   0.01, batch size  1000, episode return 15117998.8
# Episode 170, epsilon   0.01, batch size  1000, episode return 8240642.1
# Episode 171, epsilon   0.01, batch size  1000, episode return 7250414.5
# Episode 172, epsilon   0.01, batch size  1000, episode return 6587372.9
# Episode 173, epsilon   0.01, batch size  1000, episode return 8662530.2
# Episode 174, epsilon   0.01, batch size  1000, episode return 9002121.2
# Episode 175, epsilon   0.01, batch size  1000, episode return 8304115.3
# Episode 176, epsilon   0.01, batch size  1000, episode return 7849587.2
# Episode 177, epsilon   0.01, batch size  1000, episode return 8280592.4
# Episode 178, epsilon   0.01, batch size  1000, episode return 8183994.1
# Episode 179, epsilon   0.01, batch size  1000, episode return 8399166.2
# Episode 180, epsilon   0.01, batch size  1000, episode return 7091263.2
# Episode 181, epsilon   0.01, batch size  1000, episode return 9106556.5
# Episode 182, epsilon   0.01, batch size  1000, episode return 6777395.6
# Episode 183, epsilon   0.01, batch size  1000, episode return 7193950.9
# Episode 184, epsilon   0.01, batch size  1000, episode return 9446974.4
# Episode 185, epsilon   0.01, batch size  1000, episode return 7918556.1
# Episode 186, epsilon   0.01, batch size  1000, episode return 9857612.2
# Episode 187, epsilon   0.01, batch size  1000, episode return 10716435.8
# Episode 188, epsilon   0.01, batch size  1000, episode return 13225122.9
# Episode 189, epsilon   0.01, batch size  1000, episode return 10445994.5
# Episode 190, epsilon   0.01, batch size  1000, episode return 13668055.7
# Episode 191, epsilon   0.01, batch size  1000, episode return 8399374.5
# Episode 192, epsilon   0.01, batch size  1000, episode return 12196889.9
# Episode 193, epsilon   0.01, batch size  1000, episode return 8952970.9
# Episode 194, epsilon   0.01, batch size  1000, episode return 8977164.0
# Episode 195, epsilon   0.01, batch size  1000, episode return 6777395.6
# Episode 196, epsilon   0.01, batch size  1000, episode return 10124566.5
# Episode 197, epsilon   0.01, batch size  1000, episode return 9814313.7
# Episode 198, epsilon   0.01, batch size  1000, episode return 8931482.0
# Episode 199, epsilon   0.01, batch size  1000, episode return 8579636.7
# Episode 200, epsilon   0.01, batch size  1000, episode return 9801803.8

# %%
import os
torch.save(DQN, os.path.join(os.getcwd(), "models/DQN2.pt"))
